# %%
import matplotlib.pyplot as plt 
x = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6] 
y = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]

# %%
plt.scatter(x,y)
plt.show()

# %%
import numpy as np 
def estimate_coef(x, y): 
 n = np.size(x) 
 m_x = np.mean(x) 
 m_y = np.mean(y) 
 SS_xy = n*np.sum(y*x) -(np.sum(x)*np.sum(y)) 
 SS_xx = n*np.sum(x*x) - (np.sum(x)*np.sum(x)) 
 m = SS_xy / SS_xx 
 c = (np.sum(y) - m*np.sum(x))/n 
 return (m,c)

# %%
def plot_regression_line(x, y, m, c): 
 plt.scatter(x, y, color = "m", marker = "o", s = 30) 
 y_pred = m*x+c 
 plt.plot(x, y_pred, color = "g") 
 plt.xlabel('x') 
 plt.ylabel('y') 
 plt.show()

# %%
if __name__ == "__main__": 
 x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6]) 
 y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86]) 
 m, c = estimate_coef(x, y) 
 print("NAME: R U SUGIRDHA")
 print("CB.SC.I5DAS21062")
 print("Estimated coefficients: Slope = {:.2f}, Intercept = {:.2f}".format(m, c)) 
 plot_regression_line(x, y, m, c)
# Out:
# NAME: R U SUGIRDHA
# CB.SC.I5DAS21062
# Estimated coefficients: Slope = -1.75, Intercept = 103.11
